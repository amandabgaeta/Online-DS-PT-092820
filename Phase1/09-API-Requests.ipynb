# %% [markdown]
# # APIs - Gathering Data Using Requests

# %% [markdown]
# ## The Many Use Cases For APIs
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ### Learning Goals:
#
#   - Identify and discuss APIs
#   - Discuss and explain different request (GET, POST, PUT, DELETE) and CRUD operations
#   - Explore the attributes of a response object
#   - Check the status of a request and interpret status codes
#   - Access data from an API using the requests library
#   - Create a pandas dataframe from the data returned from an API and visualize the data

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information you might want through their API
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? **Every API is different!** There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Types of Requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it locally
# !pip install requests
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests) (1.25.10)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from requests) (2.10)

# %%
# Create a GET request, then check the type of object

r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"14007707440","type":"PushEvent","actor":{"id":1642008,"login":"krlsdu","display_login":"krlsdu","gravatar_id":"","url":"https://api.github.com/users/krlsdu","avatar_url":"https://avatars.githubusercontent.com/u/1642008?"},"repo":{"id":308128684,"name":"krlsdu/php-getting-started","url":"https://api.github.com/repos/krlsdu/php-getting-started"},"payload":{"push_id":5936810455,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"6c6cebb878deefd39e3b6221b6bb330eaf804ccc","before":"e533216b9607e80f29fb812778239a824931f3a6","commits":[{"sha":"6c6cebb878deefd39e3b6221b6bb330eaf804ccc","author":{"email":"krlsdu@gmail.com","name":"krlsdu"},"message":"added database access","distinct":true,"url":"https://api.github.com/repos/krlsdu/php-getting-started/commits/6c6cebb878deefd39e3b6221b6bb330eaf804ccc"}]},"public":true,"created_at":"2020-10-28T22:04:43Z"},{"id":"14007707442","type":"PushEvent","actor":{"id":70607003,"login":"bswan0002","display_login":"bswan0002","gravatar_id":"","url":"https://api.github.com/users/bswan0002","avatar_url":"https://avatars.githubusercontent.com/u/70607003?"},"repo":{"id":306731196,"name":"bswan0002/programming-univbasics-nds-green-grocer-part-2-sea01-seng-ft-111620","url":"https://api.github.com/repos/bswan0002/programming-univbasics-nds-green-grocer-part-2-sea01-seng-ft-111620"},"payload":{"push_id":5936810460,"size":1,"distinct_size":1,"ref":"refs/heads/wip","head":"848e1a8f556a2878dcff3d4fddfba72df424e905","before":"717f80a5b48bf954a70a6b0b624511d85465eaea","commits":[{"sha":"848e1a8f556a2878dcff3d4fddfba72df424e905","author":{"email":"bswan0002@gmail.com","name":"Ben Swanson"},"message":"Automatically backed up by Learn","distinct":true,"url":"https://api.github.com/repos/bswan0002/programming-univbasics-nds-green-grocer-part-2-sea01-seng-ft-111620/commits/848e1a8f556a2878dcff3d4fddfba72df424e905"}]},"public":true,"created_at":"2020-10-28T22:04:43Z"},{"id":"14007707436","type":"IssueCommentEvent","actor":{"id":219819,"login":"jamesinc","display_login":"jamesinc","gravatar_id":"","url":"https://api.github.com/users/jamesinc","avatar_url":"https://avatars.githubusercontent.com/u/219819?"},"repo":{"id":62799996,"name":"fluxcd/flux","url":"https://api.github.com/repos/fluxcd/flux"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/fluxcd/flux/issues/3229","repository_url":"https://api.github.com/repos/fluxcd/flux","labels_url":"https://api.github.com/repos/fluxcd/flux/issues/3229/labels{/name}","comments_url":"https://api.github.com/repos/fluxcd/flux/issues/3229/comments","events_url":"https://api.github.com/repos/fluxcd/flux/issues/3229/events","html_url":"https://github.com/fluxcd/flux/pull/3229","id":672870182,"node_id":"MDExOlB1bGxSZXF1ZXN0NDYyODMxMzMz","number":3229,"title":"whitelist two environment variables for AWS IAM roles in Kubernetes","user":{"login":"mattwillsher","id":1581499,"node_id":"MDQ6VXNlcjE1ODE0OTk=","avatar_url":"https://avatars3.githubusercontent.com/u/1581499?v=4","gravatar_id":"","url":"https://api.github.com/users/mattwillsher","html_url":"https://github.com/mattwillsher","followers_url":"https://api.github.com/users/mattwillsher/followers","following_url":"https://api.github.com/users/mattwillsher/following{/other_user}","gists_url":"https://api.github.com/users/mattwillsher/gists{/gist_id}","starred_url":"https://api.github.com/users/mattwillsher/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/mattwillsher/subscriptions","organizations_url":"https://api.github.com/users/mattwillsher/orgs","repos_url":"https://api.github.com/users/mattwillsher/repos","events_url":"https://api.github.com/users/mattwillsher/events{/privacy}","received_events_url":"https://api.github.com/users/mattwillsher/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":2,"created_at":"2020-08-04T15:13:06Z","updated_at":"2020-10-28T22:04:43Z","cl ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://2.python-requests.org//en/v0.10.6/api/) in the documentation.

# %%
# Headers - another attribute, what does this show us?
r.headers
# Out:
# {'server': 'GitHub.com', 'date': 'Wed, 28 Oct 2020 22:09:43 GMT', 'content-type': 'application/json; charset=utf-8', 'status': '200 OK', 'cache-control': 'public, max-age=60, s-maxage=60', 'vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'etag': 'W/"1faf954b35b10d37bd5380c91a1991ada3ce2a21ecf61d737742016a7a92a911"', 'last-modified': 'Wed, 28 Oct 2020 22:04:43 GMT', 'x-poll-interval': '60', 'x-github-media-type': 'github.v3; format=json', 'link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=9>; rel="last"', 'access-control-expose-headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, Deprecation, Sunset', 'access-control-allow-origin': '*', 'strict-transport-security': 'max-age=31536000; includeSubdomains; preload', 'x-frame-options': 'deny', 'x-content-type-options': 'nosniff', 'x-xss-protection': '1; mode=block', 'referrer-policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'content-security-policy': "default-src 'none'", 'content-encoding': 'gzip', 'X-Ratelimit-Limit': '60', 'X-Ratelimit-Remaining': '59', 'X-Ratelimit-Reset': '1603926583', 'X-Ratelimit-Used': '1', 'Accept-Ranges': 'bytes', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'D126:4665:3F3299:9E3FF7:5F99EC27'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code
# Out:
# 200

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '14007707440',
#   'type': 'PushEvent',
#   'actor': {'id': 1642008,
#    'login': 'krlsdu',
#    'display_login': 'krlsdu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/krlsdu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1642008?'},
#   'repo': {'id': 308128684,
#    'name': 'krlsdu/php-getting-started',
#    'url': 'https://api.github.com/repos/krlsdu/php-getting-started'},
#   'payload': {'push_id': 5936810455,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6c6cebb878deefd39e3b6221b6bb330eaf804ccc',
#    'before': 'e533216b9607e80f29fb812778239a824931f3a6',
#    'commits': [{'sha': '6c6cebb878deefd39e3b6221b6bb330eaf804ccc',
#      'author': {'email': 'krlsdu@gmail.com', 'name': 'krlsdu'},
#      'message': 'added database access',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/krlsdu/php-getting-started/commits/6c6cebb878deefd39e3b6221b6bb330eaf804ccc'}]},
#   'public': True,
#   'created_at': '2020-10-28T22:04:43Z'},
#  {'id': '14007707442',
#   'type': 'PushEvent',
#   'actor': {'id': 70607003,
#    'login': 'bswan0002',
#    'display_login': 'bswan0002',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bswan0002',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70607003?'},
#   'repo': {'id': 306731196,
#    'name': 'bswan0002/programming-univbasics-nds-green-grocer-part-2-sea01-seng-ft-111620',
#    'url': 'https://api.github.com/repos/bswan0002/programming-univbasics-nds-green-grocer-part-2-sea01-seng-ft-111620'},
#   'payload': {'push_id': 5936810460,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '848e1a8f556a2878dcff3d4fddfba72df424e905',
#    'before': '717f80a5b48bf954a70a6b0b624511d85465eaea',
#    'commits': [{'sha': '848e1a8f556a2878dcff3d4fddfba72df424e905',
#      'author': {'email': 'bswan0002@gmail.com', 'name': 'Ben Swanson'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bswan0002/programming-univbasics-nds-green-grocer-part-2-sea01-seng-ft-111620/commits/848e1a8f556a2878dcff3d4fddfba72df424e905'}]},
#   'public': True,
#   'created_at': '2020-10-28T22:04:43Z'},
#  {'id': '14007707436',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 219819,
#    'login': 'jamesinc',
#    'display_login': 'jamesinc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jamesinc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/219819?'},
#   'repo': {'id': 62799996,
#    'name': 'fluxcd/flux',
#    'url': 'https://api.github.com/repos/fluxcd/flux'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/fluxcd/flux/issues/3229',
#     'repository_url': 'https://api.github.com/repos/fluxcd/flux',
#     'labels_url': 'https://api.github.com/repos/fluxcd/flux/issues/3229/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/fluxcd/flux/issues/3229/comments',
#     'events_url': 'https://api.github.com/repos/fluxcd/flux/issues/3229/events',
#     'html_url': 'https://github.com/fluxcd/flux/pull/3229',
#     'id': 672870182,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDYyODMxMzMz',
#     'number': 3229,
#     'title': 'whitelist two environment variables for AWS IAM roles in Kubernetes',
#     'user': {'login': 'mattwillsher',
#      'id': 1581499,
#      'node_id': 'MDQ6VXNlcjE1ODE0OTk=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/1581499?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mattwillsher',
#      'html_url': 'https://github.com/mattwillsher',
#      'followers_url': 'https://api.github.com/users/mattwillsher/followers',
#      'following_url': 'https://api.github.com/users/mattwillsher/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mattwillsher/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mattwillsher/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mattwillsher/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mattwillsher/orgs',
#      'repos_url': 'https://api.github.com/users/mattwillsher/repos',
#      'events_url': 'https://api.github.com/users/mattwillsher/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mattwillsher/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2020-08-04T15:13:06Z',
#     'updated_at': '2020-10-28T22:04:43Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/fluxcd/flux/pulls/3229',
#      'html_url': 'https://github.com/fluxcd/flux/pull/3229',
#      'diff_url': 'https://github.com/fluxcd/flux/pull/3229.diff',
#      'patch_url': 'https://github.com/fluxcd/flux/pull/3229.patch'},
#     'body': '* AWS_WEB_IDENTITY_TOKEN_FILE\r\n* AWS_ROLE_ARN\r\n\r\nSuch that the AWS CodeCommit git credential helper can be used in the fluxcd container so that static git credentials are not needed. This does require additional components in the fluxcd container. For example:\r\n\r\n```\r\nFROM fluxcd/flux:1.20.0\r\n\r\nARG PY3PIP_VERSION=20.1.1-r0\r\nARG AWSCLI_VERSION=1.18.55-r0\r\nARG GITREMOTECODECOMMIT_VERSION=1.13\r\n\r\nRUN /sbin/apk add --no-cache py3-pip="$PY3PIP_VERSION" aws-cli="$AWSCLI_VERSION"\r\nRUN pip3 install git-remote-codecommit=="$GITREMOTECODECOMMIT_VERSION"\r\nRUN git config --global credential.helper \'!aws codecommit credential-helper $@\' \\\r\n    && git config --global credential.UseHttpPath true\r\n```\r\n\r\n\r\nAn IAM role for the service account can then be used to authentication to CodeCommit (https://docs.aws.amazon.com/eks/latest/userguide/iam-roles-for-service-accounts.html), with `--git-url` set to the HTTPS URL of the CodeCommit repo as given by aws, and a patch to the flux ServiceAccount giving the IAM role ARN:\r\n\r\n```\r\n---\r\napiVersion: v1\r\nkind: ServiceAccount\r\nmetadata:\r\n  namespace: flux\r\n  name: flux\r\n  annotations:\r\n    eks.amazonaws.com/role-arn: arn:aws:iam::123456789012:role/MyFluxRole\r\n```\r\n\r\n\r\nThis goes someway to resolve #2895 \r\n\r\n<!--\r\n# General contribution criteria\r\n\r\nPlease have a look at our contribution guidelines: https://github.com/fluxcd/flux/blob/master/CONTRIBUTING.md\r\nParticularly the sections about the:\r\n\r\n - DCO;\r\n - contribution workflow; and\r\n - how to get your fix accepted\r\n\r\nTo help the maintainers out when they\'re writing release notes, please\r\ntry to include a sentence or two here describing your change for end\r\nusers. See the CHANGELOG.md file in the top-level directory for examples.\r\n\r\nParticularly for ground-breaking changes and new features, it\'s important to\r\nmake users and developers aware of what\'s changing and where those changes\r\nwere documented or discussed.\r\n\r\nEven for smaller changes it\'s useful to see things documented as well, as it\r\ngives everybody a chance to see at a glance what\'s coming up in the next\r\nrelease. It makes the life of the project maintainer a lot easier as well.\r\n\r\nThe following short checklist can be used to make sure your PR is of good\r\nquality, and can be merged easily:\r\n\r\n- [ ] if it resolves an issue;\r\n      is a reference (i.e. #1) to this issue included?\r\n- [ ] if it introduces a new functionality or configuration flag;\r\n      did you document this in the references or guides?\r\n- [ ] optional but much appreciated;\r\n      do you think many users would profit from a dedicated setting\r\n      for this functionality in the Helm chart?\r\n-->\r\n',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/fluxcd/flux/issues/comments/718235330',
#     'html_url': 'https://github.com/fluxcd/flux/pull/3229#issuecomment-718235330',
#     'issue_url': 'https://api.github.com/repos/fluxcd/flux/issues/3229',
#     'id': 718235330,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDcxODIzNTMzMA==',
#     'user': {'login': 'jamesinc',
#      'id': 219819,
#      'node_id': 'MDQ6VXNlcjIxOTgxOQ==',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/219819?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jamesinc',
#      'html_url': 'https://github.com/jamesinc',
#      'followers_url': 'https://api.github.com/users/jamesinc/followers',
#      'following_url': 'https://api.github.com/users/jamesinc/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jamesinc/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jamesinc/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jamesinc/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jamesinc/orgs',
#      'repos_url': 'https://api.github.com/users/jamesinc/repos',
#      'events_url': 'https://api.github.com/users/jamesinc/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jamesinc/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-10-28T22:04:43Z',
#     'updated_at': '2020-10-28T22:04:43Z',
#     'author_association': 'NONE',
#     'body': 'Keen for this PR to be merged',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-10-28T22:04:43Z',
#   'org': {'id': 52158677,
#    'login': 'fluxcd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/fluxcd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52158677?'}},
#  {'id': '14007707435',
#   'type': 'PushEvent',
#   'actor': {'id': 50547464,
#    'login': 'RyanFlm',
#    'display_login': 'RyanFlm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RyanFlm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50547464?'},
#   'repo': {'id': 261432342,
#    'name': 'Bergflix/frontend',
#    'url': 'https://api.github.com/repos/Bergflix/frontend'},
#   'payload': {'push_id': 5936810451,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c2ab7ff1617cec790adb9e24fec8f552c734ce6c',
#    'before': 'ee07fbe3f5a71517e235cfc16fa80f3e438a4775',
#    'commits': [{'sha': 'c2ab7ff1617cec790adb9e24fec8f552c734ce6c',
#      'author': {'email': 'info@apelma.de', 'name': 'RyanFlm'},
#      'message': 'Splitting up the backend into multiple functions',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Bergflix/frontend/commits/c2ab7ff1617cec790adb9e24fec8f552c734ce6c'}]},
#   'public': True,
#   'created_at': '2020-10-28T22:04:43Z',
#   'org': {'id': 64833267,
#    'login': 'Bergflix',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Bergflix',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64833267?'}},
#  {'id': '14007707437',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 5259296,
#    'login': 'GezimSejdiu',
#    'display_login': 'GezimSejdiu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GezimSejdiu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5259296?'},
#   'repo': {'id': 115619697,
#    'name': 'GezimSejdiu/gezimsejdiu.github.io',
#    'url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io'},
#   'payload': {'action': 'closed',
#    'number': 5,
#    'pull_request': {'url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/pulls/5',
#     'id': 379496902,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzc5NDk2OTAy',
#     'html_url': 'https://github.com/GezimSejdiu/gezimsejdiu.github.io/pull/5',
#     'diff_url': 'https://github.com/GezimSejdiu/gezimsejdiu.github.io/pull/5.diff',
#     'patch_url': 'https://github.com/GezimSejdiu/gezimsejdiu.github.io/pull/5.patch',
#     'issue_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/issues/5',
#     'number': 5,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump loofah from 2.2.3 to 2.4.0',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [loofah](https://github.com/flavorjones/loofah) from 2.2.3 to 2.4.0.\n<details>\n<summary>Release notes</summary>\n\n*Sourced from [loofah\'s releases](https://github.com/flavorjones/loofah/releases).*\n\n> ## 2.4.0 / 2019-11-25\r\n> \r\n> ### Features\r\n> \r\n> * Allow CSS property `max-width` [#175](https://github-redirect.dependabot.com/flavorjones/loofah/issues/175) (Thanks, [@&#8203;bchaney](https://github.com/bchaney)!)\r\n> * Allow CSS sizes expressed in `rem` [#176, [#177](https://github-redirect.dependabot.com/flavorjones/loofah/issues/177)]\r\n> * Add `frozen_string_literal: true` magic comment to all `lib` files. [#118](https://github-redirect.dependabot.com/flavorjones/loofah/issues/118)\r\n> \n> ## 2.3.1 / 2019-10-22\r\n> \r\n> ### Security\r\n> \r\n> Address CVE-2019-15587: Unsanitized JavaScript may occur in sanitized output when a crafted SVG element is republished.\r\n> \r\n> This CVE\'s public notice is at [flavorjones/loofah#171](https://github-redirect.dependabot.com/flavorjones/loofah/issues/171)\r\n> \n> ## 2.3.0 / 2019-09-28\r\n> \r\n> ### Features\r\n> \r\n> * Expand set of allowed protocols to include `tel:` and `line:`. [#104, [#147](https://github-redirect.dependabot.com/flavorjones/loofah/issues/147)]\r\n> * Expand set of allowed CSS functions. [related to [#122](https://github-redirect.dependabot.com/flavorjones/loofah/issues/122)]\r\n> * Allow greater precision in shorthand CSS values. [#149](https://github-redirect.dependabot.com/flavorjones/loofah/issues/149) (Thanks, [@&#8203;danfstucky](https://github.com/danfstucky)!)\r\n> * Allow CSS property `list-style` [#162](https://github-redirect.dependabot.com/flavorjones/loofah/issues/162) (Thanks, [@&#8203;jaredbeck](https://github.com/jaredbeck)!)\r\n> * Allow CSS keywords `thick` and `thin` [#168](https://github-redirect.dependabot.com/flavorjones/loofah/issues/168) (Thanks, [@&#8203;georgeclaghorn](https://github.com/georgeclaghorn)!)\r\n> * Allow HTML property `contenteditable` [#167](https://github-redirect.dependabot.com/flavorjones/loofah/issues/167) (Thanks, [@&#8203;andreynering](https://github.com/andreynering)!)\r\n> \r\n> \r\n> ### Bug fixes\r\n> \r\n> * CSS hex values are no longer limited to lowercase hex. Previously uppercase hex were scrubbed. [#165](https://github-redirect.dependabot.com/flavorjones/loofah/issues/165) (Thanks, [@&#8203;asok](https://github.com/asok)!)\r\n> \r\n> \r\n> ### Deprecations / Name Changes\r\n> \r\n> The following method and constants are hereby deprecated, and will be completely removed in a future release:\r\n> \r\n> * Deprecate `Loofah::Helpers::ActionView.white_list_sanitizer`, please use `Loofah::Helpers::ActionView.safe_list_sanitizer` instead.\r\n> * Deprecate `Loofah::Helpers::ActionView::WhiteListSanitizer`, please use `Loofah::Helpers::ActionView::SafeListSanitizer` instead.\r\n> * Deprecate `Loofah::HTML5::WhiteList`, please use `Loofah::HTML5::SafeList` instead.\r\n> \r\n> Thanks to [@&#8203;JuanitoFatas](https://github.com/JuanitoFatas) for submitting these changes in [#164](https://github-redirect.dependabot.com/flavorjones/loofah/issues/164) and for making the language used in Loofah more inclusive.\r\n> \r\n> \r\n</details>\n<details>\n<summary>Changelog</summary>\n\n*Sourced from [loofah\'s changelog](https://github.com/flavorjones/loofah/blob/master/CHANGELOG.md).*\n\n> ## 2.4.0 / 2019-11-25\n> \n> ### Features\n> \n> * Allow CSS property `max-width` [#175](https://github-redirect.dependabot.com/flavorjones/loofah/issues/175) (Thanks, [@&#8203;bchaney](https://github.com/bchaney)!)\n> * Allow CSS sizes expressed in `rem` [#176, [#177](https://github-redirect.dependabot.com/flavorjones/loofah/issues/177)]\n> * Add `frozen_string_literal: true` magic comment to all `lib` files. [#118](https://github-redirect.dependabot.com/flavorjones/loofah/issues/118)\n> \n> \n> ## 2.3.1 / 2019-10-22\n> \n> ### Security\n> \n> Address CVE-2019-15587: Unsanitized JavaScript may occur in ...
#     'created_at': '2020-02-25T10:33:37Z',
#     'updated_at': '2020-10-28T22:04:43Z',
#     'closed_at': '2020-10-28T22:04:43Z',
#     'merged_at': '2020-10-28T22:04:43Z',
#     'merge_commit_sha': '429515a36a9b4d160242814c40d47d53830d005f',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1577470691,
#       'node_id': 'MDU6TGFiZWwxNTc3NDcwNjkx',
#       'url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/pulls/5/commits',
#     'review_comments_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/pulls/5/comments',
#     'review_comment_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/issues/5/comments',
#     'statuses_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/statuses/04639eb8323637b6c6ed01f85eb1ded8a8c63777',
#     'head': {'label': 'GezimSejdiu:dependabot/bundler/loofah-2.4.0',
#      'ref': 'dependabot/bundler/loofah-2.4.0',
#      'sha': '04639eb8323637b6c6ed01f85eb1ded8a8c63777',
#      'user': {'login': 'GezimSejdiu',
#       'id': 5259296,
#       'node_id': 'MDQ6VXNlcjUyNTkyOTY=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/5259296?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/GezimSejdiu',
#       'html_url': 'https://github.com/GezimSejdiu',
#       'followers_url': 'https://api.github.com/users/GezimSejdiu/followers',
#       'following_url': 'https://api.github.com/users/GezimSejdiu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/GezimSejdiu/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/GezimSejdiu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/GezimSejdiu/subscriptions',
#       'organizations_url': 'https://api.github.com/users/GezimSejdiu/orgs',
#       'repos_url': 'https://api.github.com/users/GezimSejdiu/repos',
#       'events_url': 'https://api.github.com/users/GezimSejdiu/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/GezimSejdiu/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 115619697,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTU2MTk2OTc=',
#       'name': 'gezimsejdiu.github.io',
#       'full_name': 'GezimSejdiu/gezimsejdiu.github.io',
#       'private': False,
#       'owner': {'login': 'GezimSejdiu',
#        'id': 5259296,
#        'node_id': 'MDQ6VXNlcjUyNTkyOTY=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/5259296?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/GezimSejdiu',
#        'html_url': 'https://github.com/GezimSejdiu',
#        'followers_url': 'https://api.github.com/users/GezimSejdiu/followers',
#        'following_url': 'https://api.github.com/users/GezimSejdiu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/GezimSejdiu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/GezimSejdiu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/GezimSejdiu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/GezimSejdiu/orgs',
#        'repos_url': 'https://api.github.com/users/GezimSejdiu/repos',
#        'events_url': 'https://api.github.com/users/GezimSejdiu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/GezimSejdiu/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/GezimSejdiu/gezimsejdiu.github.io',
#       'description': 'Personal Academic Site',
#       'fork': False,
#       'url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io',
#       'forks_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/forks',
#       'keys_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/teams',
#       'hooks_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/hooks',
#       'issue_events_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/events',
#       'assignees_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/tags',
#       'blobs_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/languages',
#       'stargazers_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/stargazers',
#       'contributors_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/contributors',
#       'subscribers_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/subscribers',
#       'subscription_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/subscription',
#       'commits_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/merges',
#       'archive_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/downloads',
#       'issues_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/deployments',
#       'created_at': '2017-12-28T12:08:56Z',
#       'updated_at': '2020-10-28T22:04:30Z',
#       'pushed_at': '2020-10-28T22:04:43Z',
#       'git_url': 'git://github.com/GezimSejdiu/gezimsejdiu.github.io.git',
#       'ssh_url': 'git@github.com:GezimSejdiu/gezimsejdiu.github.io.git',
#       'clone_url': 'https://github.com/GezimSejdiu/gezimsejdiu.github.io.git',
#       'svn_url': 'https://github.com/GezimSejdiu/gezimsejdiu.github.io',
#       'homepage': 'https://gezimsejdiu.github.io/',
#       'size': 4764,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'GezimSejdiu:master',
#      'ref': 'master',
#      'sha': '87b373ed52674fd7295629fd15201c8ebf8ab779',
#      'user': {'login': 'GezimSejdiu',
#       'id': 5259296,
#       'node_id': 'MDQ6VXNlcjUyNTkyOTY=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/5259296?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/GezimSejdiu',
#       'html_url': 'https://github.com/GezimSejdiu',
#       'followers_url': 'https://api.github.com/users/GezimSejdiu/followers',
#       'following_url': 'https://api.github.com/users/GezimSejdiu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/GezimSejdiu/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/GezimSejdiu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/GezimSejdiu/subscriptions',
#       'organizations_url': 'https://api.github.com/users/GezimSejdiu/orgs',
#       'repos_url': 'https://api.github.com/users/GezimSejdiu/repos',
#       'events_url': 'https://api.github.com/users/GezimSejdiu/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/GezimSejdiu/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 115619697,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMTU2MTk2OTc=',
#       'name': 'gezimsejdiu.github.io',
#       'full_name': 'GezimSejdiu/gezimsejdiu.github.io',
#       'private': False,
#       'owner': {'login': 'GezimSejdiu',
#        'id': 5259296,
#        'node_id': 'MDQ6VXNlcjUyNTkyOTY=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/5259296?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/GezimSejdiu',
#        'html_url': 'https://github.com/GezimSejdiu',
#        'followers_url': 'https://api.github.com/users/GezimSejdiu/followers',
#        'following_url': 'https://api.github.com/users/GezimSejdiu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/GezimSejdiu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/GezimSejdiu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/GezimSejdiu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/GezimSejdiu/orgs',
#        'repos_url': 'https://api.github.com/users/GezimSejdiu/repos',
#        'events_url': 'https://api.github.com/users/GezimSejdiu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/GezimSejdiu/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/GezimSejdiu/gezimsejdiu.github.io',
#       'description': 'Personal Academic Site',
#       'fork': False,
#       'url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io',
#       'forks_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/forks',
#       'keys_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/teams',
#       'hooks_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/hooks',
#       'issue_events_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/events',
#       'assignees_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/tags',
#       'blobs_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/languages',
#       'stargazers_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/stargazers',
#       'contributors_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/contributors',
#       'subscribers_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/subscribers',
#       'subscription_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/subscription',
#       'commits_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/merges',
#       'archive_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/downloads',
#       'issues_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/deployments',
#       'created_at': '2017-12-28T12:08:56Z',
#       'updated_at': '2020-10-28T22:04:30Z',
#       'pushed_at': '2020-10-28T22:04:43Z',
#       'git_url': 'git://github.com/GezimSejdiu/gezimsejdiu.github.io.git',
#       'ssh_url': 'git@github.com:GezimSejdiu/gezimsejdiu.github.io.git',
#       'clone_url': 'https://github.com/GezimSejdiu/gezimsejdiu.github.io.git',
#       'svn_url': 'https://github.com/GezimSejdiu/gezimsejdiu.github.io',
#       'homepage': 'https://gezimsejdiu.github.io/',
#       'size': 4764,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/pulls/5'},
#      'html': {'href': 'https://github.com/GezimSejdiu/gezimsejdiu.github.io/pull/5'},
#      'issue': {'href': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/issues/5'},
#      'comments': {'href': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/issues/5/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/pulls/5/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/pulls/5/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/GezimSejdiu/gezimsejdiu.github.io/statuses/04639eb8323637b6c6ed01f85eb1ded8a8c63777'}},
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'GezimSejdiu',
#      'id': 5259296,
#      'node_id': 'MDQ6VXNlcjUyNTkyOTY=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/5259296?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/GezimSejdiu',
#      'html_url': 'https://github.com/GezimSejdiu',
#      'followers_url': 'https://api.github.com/users/GezimSejdiu/followers',
#      'following_url': 'https://api.github.com/users/GezimSejdiu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/GezimSejdiu/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/GezimSejdiu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/GezimSejdiu/subscriptions',
#      'organizations_url': 'https://api.github.com/users/GezimSejdiu/orgs',
#      'repos_url': 'https://api.github.com/users/GezimSejdiu/repos',
#      'events_url': 'https://api.github.com/users/GezimSejdiu/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/GezimSejdiu/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 2,
#     'deletions': 2,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-10-28T22:04:43Z'},
#  {'id': '14007707434',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 46856265,
#    'login': 'buddhi44',
#    'display_login': 'buddhi44',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/buddhi44',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46856265?'},
#   'repo': {'id': 275771543,
#    'name': 'buddhi44/test1',
#    'url': 'https://api.github.com/repos/buddhi44/test1'},
#   'payload': {'action': 'opened',
#    'number': 3,
#    'pull_request': {'url': 'https://api.github.com/repos/buddhi44/test1/pulls/3',
#     'id': 511864097,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NTExODY0MDk3',
#     'html_url': 'https://github.com/buddhi44/test1/pull/3',
#     'diff_url': 'https://github.com/buddhi44/test1/pull/3.diff',
#     'patch_url': 'https://github.com/buddhi44/test1/pull/3.patch',
#     'issue_url': 'https://api.github.com/repos/buddhi44/test1/issues/3',
#     'number': 3,
#     'state': 'open',
#     'locked': False,
#     'title': 'C',
#     'user': {'login': 'buddhi44',
#      'id': 46856265,
#      'node_id': 'MDQ6VXNlcjQ2ODU2MjY1',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/46856265?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/buddhi44',
#      'html_url': 'https://github.com/buddhi44',
#      'followers_url': 'https://api.github.com/users/buddhi44/followers',
#      'following_url': 'https://api.github.com/users/buddhi44/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/buddhi44/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/buddhi44/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/buddhi44/subscriptions',
#      'organizations_url': 'https://api.github.com/users/buddhi44/orgs',
#      'repos_url': 'https://api.github.com/users/buddhi44/repos',
#      'events_url': 'https://api.github.com/users/buddhi44/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/buddhi44/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2020-10-28T22:04:43Z',
#     'updated_at': '2020-10-28T22:04:43Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/buddhi44/test1/pulls/3/commits',
#     'review_comments_url': 'https://api.github.com/repos/buddhi44/test1/pulls/3/comments',
#     'review_comment_url': 'https://api.github.com/repos/buddhi44/test1/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/buddhi44/test1/issues/3/comments',
#     'statuses_url': 'https://api.github.com/repos/buddhi44/test1/statuses/0037077a5c6e68b4d527b54f232f37df58c7a1b9',
#     'head': {'label': 'buddhi44:c',
#      'ref': 'c',
#      'sha': '0037077a5c6e68b4d527b54f232f37df58c7a1b9',
#      'user': {'login': 'buddhi44',
#       'id': 46856265,
#       'node_id': 'MDQ6VXNlcjQ2ODU2MjY1',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/46856265?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/buddhi44',
#       'html_url': 'https://github.com/buddhi44',
#       'followers_url': 'https://api.github.com/users/buddhi44/followers',
#       'following_url': 'https://api.github.com/users/buddhi44/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/buddhi44/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/buddhi44/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/buddhi44/subscriptions',
#       'organizations_url': 'https://api.github.com/users/buddhi44/orgs',
#       'repos_url': 'https://api.github.com/users/buddhi44/repos',
#       'events_url': 'https://api.github.com/users/buddhi44/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/buddhi44/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 275771543,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNzU3NzE1NDM=',
#       'name': 'test1',
#       'full_name': 'buddhi44/test1',
#       'private': False,
#       'owner': {'login': 'buddhi44',
#        'id': 46856265,
#        'node_id': 'MDQ6VXNlcjQ2ODU2MjY1',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/46856265?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/buddhi44',
#        'html_url': 'https://github.com/buddhi44',
#        'followers_url': 'https://api.github.com/users/buddhi44/followers',
#        'following_url': 'https://api.github.com/users/buddhi44/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/buddhi44/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/buddhi44/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/buddhi44/subscriptions',
#        'organizations_url': 'https://api.github.com/users/buddhi44/orgs',
#        'repos_url': 'https://api.github.com/users/buddhi44/repos',
#        'events_url': 'https://api.github.com/users/buddhi44/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/buddhi44/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/buddhi44/test1',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/buddhi44/test1',
#       'forks_url': 'https://api.github.com/repos/buddhi44/test1/forks',
#       'keys_url': 'https://api.github.com/repos/buddhi44/test1/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/buddhi44/test1/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/buddhi44/test1/teams',
#       'hooks_url': 'https://api.github.com/repos/buddhi44/test1/hooks',
#       'issue_events_url': 'https://api.github.com/repos/buddhi44/test1/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/buddhi44/test1/events',
#       'assignees_url': 'https://api.github.com/repos/buddhi44/test1/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/buddhi44/test1/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/buddhi44/test1/tags',
#       'blobs_url': 'https://api.github.com/repos/buddhi44/test1/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/buddhi44/test1/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/buddhi44/test1/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/buddhi44/test1/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/buddhi44/test1/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/buddhi44/test1/languages',
#       'stargazers_url': 'https://api.github.com/repos/buddhi44/test1/stargazers',
#       'contributors_url': 'https://api.github.com/repos/buddhi44/test1/contributors',
#       'subscribers_url': 'https://api.github.com/repos/buddhi44/test1/subscribers',
#       'subscription_url': 'https://api.github.com/repos/buddhi44/test1/subscription',
#       'commits_url': 'https://api.github.com/repos/buddhi44/test1/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/buddhi44/test1/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/buddhi44/test1/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/buddhi44/test1/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/buddhi44/test1/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/buddhi44/test1/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/buddhi44/test1/merges',
#       'archive_url': 'https://api.github.com/repos/buddhi44/test1/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/buddhi44/test1/downloads',
#       'issues_url': 'https://api.github.com/repos/buddhi44/test1/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/buddhi44/test1/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/buddhi44/test1/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/buddhi44/test1/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/buddhi44/test1/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/buddhi44/test1/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/buddhi44/test1/deployments',
#       'created_at': '2020-06-29T08:14:44Z',
#       'updated_at': '2020-10-28T21:39:24Z',
#       'pushed_at': '2020-10-28T22:00:21Z',
#       'git_url': 'git://github.com/buddhi44/test1.git',
#       'ssh_url': 'git@github.com:buddhi44/test1.git',
#       'clone_url': 'https://github.com/buddhi44/test1.git',
#       'svn_url': 'https://github.com/buddhi44/test1',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'buddhi44:b',
#      'ref': 'b',
#      'sha': '72560d1f701e4b1bb0b4765bc29eb81d4bb12b79',
#      'user': {'login': 'buddhi44',
#       'id': 46856265,
#       'node_id': 'MDQ6VXNlcjQ2ODU2MjY1',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/46856265?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/buddhi44',
#       'html_url': 'https://github.com/buddhi44',
#       'followers_url': 'https://api.github.com/users/buddhi44/followers',
#       'following_url': 'https://api.github.com/users/buddhi44/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/buddhi44/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/buddhi44/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/buddhi44/subscriptions',
#       'organizations_url': 'https://api.github.com/users/buddhi44/orgs',
#       'repos_url': 'https://api.github.com/users/buddhi44/repos',
#       'events_url': 'https://api.github.com/users/buddhi44/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/buddhi44/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 275771543,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNzU3NzE1NDM=',
#       'name': 'test1',
#       'full_name': 'buddhi44/test1',
#       'private': False,
#       'owner': {'login': 'buddhi44',
#        'id': 46856265,
#        'node_id': 'MDQ6VXNlcjQ2ODU2MjY1',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/46856265?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/buddhi44',
#        'html_url': 'https://github.com/buddhi44',
#        'followers_url': 'https://api.github.com/users/buddhi44/followers',
#        'following_url': 'https://api.github.com/users/buddhi44/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/buddhi44/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/buddhi44/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/buddhi44/subscriptions',
#        'organizations_url': 'https://api.github.com/users/buddhi44/orgs',
#        'repos_url': 'https://api.github.com/users/buddhi44/repos',
#        'events_url': 'https://api.github.com/users/buddhi44/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/buddhi44/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/buddhi44/test1',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/buddhi44/test1',
#       'forks_url': 'https://api.github.com/repos/buddhi44/test1/forks',
#       'keys_url': 'https://api.github.com/repos/buddhi44/test1/keys{/key_id}',
# ...
#     {'sha': '219c6ff7cdbb5483f400b2fa62659e8345c51bd8',
#      'author': {'email': 'mav@FreeBSD.org', 'name': 'mav'},
#      'message': 'Use proper variable for device path.\n\nIt seems *-passthru commands were broken from the day one, since the\ndevice path is fetched into opt.dev variable and not left in argv[optind].\nThe other three wrong argv[optind] instances are just in error messages.\n\nMFC after:\t1 week\nSponsored by:\tiXsystems, Inc.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HardenedBSD/hardenedBSD/commits/219c6ff7cdbb5483f400b2fa62659e8345c51bd8'},
#     {'sha': '1cd599537c4c34546988f96ac92b7c88c89239ae',
#      'author': {'email': 'mav@FreeBSD.org', 'name': 'mav'},
#      'message': 'Fix unintentional constant rename in r367109.\n\nMFC after:\t1 week',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HardenedBSD/hardenedBSD/commits/1cd599537c4c34546988f96ac92b7c88c89239ae'},
#     {'sha': 'dac4a9db2a8dc0bdbe0dfc3bd68733530bf47114',
#      'author': {'email': 'melifaro@FreeBSD.org', 'name': 'melifaro'},
#      'message': 'Fix use-after-free in icmp6_notify_error().\n\nReported by:\tMaxime Villard <max at m00nbsd.net>\nReviewed by:\tmarkj\nMFC after:\t3 days',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HardenedBSD/hardenedBSD/commits/dac4a9db2a8dc0bdbe0dfc3bd68733530bf47114'},
#     {'sha': 'a2c155ed9bc3ffd1531c8681460a73411a03c93f',
#      'author': {'email': 'vmaffione@FreeBSD.org', 'name': 'vmaffione'},
#      'message': 'iflib: fix typo bug introduced by r367093\n\nCode was supposed to call callout_reset_sbt_on() rather than\ncallout_reset_sbt(). This resulted into passing a "cpu" value\nto a "flag" argument. A recipe for subtle errors.\n\nPR:\t248652\nReported by:\tsg@efficientip.com\nMFC with: r367093',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HardenedBSD/hardenedBSD/commits/a2c155ed9bc3ffd1531c8681460a73411a03c93f'},
#     {'sha': '1040a2141d41fdc1866f5faf581adb8540b51d7f',
#      'author': {'email': 'imp@FreeBSD.org', 'name': 'imp'},
#      'message': 'Note that sys/systm.h is special too\n\nIf you need / want to includerd sys/systm.h, it has to be just after\nparam.h/types.h. Document this existing practice. Not all kernel files\ninclude systm.h, but when you do, it should be done out of order.\n\nReviewed by: vangyzen, kib, emaste\nDifferential Review: https://reviews.freebsd.org/D26981',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HardenedBSD/hardenedBSD/commits/1040a2141d41fdc1866f5faf581adb8540b51d7f'},
#     {'sha': '4e81b08fc28491231eec3b2ec8613940fcda9c7a',
#      'author': {'email': 'imp@FreeBSD.org', 'name': 'imp'},
#      'message': "loader: add aarch64 support for zstd\n\nWe don't have NEON available in the boot loader, so we have to disable\nit. OpenZFS included ZSTD which used the wrong symbol to bring in neon\nsupport. Change to use the code that's been submitted upstream as a\npull request to both.\n\n__ARM_NEON is the proper symbol, defined in ARM C Language Extensions\nRelease 2.1 (https://developer.arm.com/documentation/ihi0053/d/). Some\nsources suggest __ARM_NEON__, but that's the obsolete spelling from\nprior versions of the standard.\n\nOpenZFS Pull Request: https://github.com/openzfs/zfs/pull/11055\nZSTD Pull Request: https://github.com/facebook/zstd/pull/2356",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HardenedBSD/hardenedBSD/commits/4e81b08fc28491231eec3b2ec8613940fcda9c7a'}]},
#   'public': True,
#   'created_at': '2020-10-28T22:04:43Z',
#   'org': {'id': 7223580,
#    'login': 'HardenedBSD',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/HardenedBSD',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7223580?'}},
#  {'id': '14007707371',
#   'type': 'MemberEvent',
#   'actor': {'id': 55128781,
#    'login': 'fyrirvari',
#    'display_login': 'fyrirvari',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fyrirvari',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55128781?'},
#   'repo': {'id': 305148410,
#    'name': 'fyrirvari/mp2-lab3-postfix',
#    'url': 'https://api.github.com/repos/fyrirvari/mp2-lab3-postfix'},
#   'payload': {'member': {'login': 'alvls',
#     'id': 5449780,
#     'node_id': 'MDQ6VXNlcjU0NDk3ODA=',
#     'avatar_url': 'https://avatars3.githubusercontent.com/u/5449780?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/alvls',
#     'html_url': 'https://github.com/alvls',
#     'followers_url': 'https://api.github.com/users/alvls/followers',
#     'following_url': 'https://api.github.com/users/alvls/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/alvls/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/alvls/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/alvls/subscriptions',
#     'organizations_url': 'https://api.github.com/users/alvls/orgs',
#     'repos_url': 'https://api.github.com/users/alvls/repos',
#     'events_url': 'https://api.github.com/users/alvls/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/alvls/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'action': 'added'},
#   'public': True,
#   'created_at': '2020-10-28T22:04:43Z'},
#  {'id': '14007707368',
#   'type': 'DeleteEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 161186500,
#    'name': 'TRIF3X/back-end-project-week',
#    'url': 'https://api.github.com/repos/TRIF3X/back-end-project-week'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/supertest-5.0.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-10-28T22:04:43Z'},
#  {'id': '14007707361',
#   'type': 'ForkEvent',
#   'actor': {'id': 12960457,
#    'login': 'helciodasilva',
#    'display_login': 'helciodasilva',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/helciodasilva',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12960457?'},
#   'repo': {'id': 210916715,
#    'name': 'caelum/apostila-devops',
#    'url': 'https://api.github.com/repos/caelum/apostila-devops'},
#   'payload': {'forkee': {'id': 308151823,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkzMDgxNTE4MjM=',
#     'name': 'apostila-devops',
#     'full_name': 'helciodasilva/apostila-devops',
#     'private': False,
#     'owner': {'login': 'helciodasilva',
#      'id': 12960457,
#      'node_id': 'MDQ6VXNlcjEyOTYwNDU3',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/12960457?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/helciodasilva',
#      'html_url': 'https://github.com/helciodasilva',
#      'followers_url': 'https://api.github.com/users/helciodasilva/followers',
#      'following_url': 'https://api.github.com/users/helciodasilva/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/helciodasilva/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/helciodasilva/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/helciodasilva/subscriptions',
#      'organizations_url': 'https://api.github.com/users/helciodasilva/orgs',
#      'repos_url': 'https://api.github.com/users/helciodasilva/repos',
#      'events_url': 'https://api.github.com/users/helciodasilva/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/helciodasilva/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/helciodasilva/apostila-devops',
#     'description': 'Apostila do curso de DevOps',
#     'fork': True,
#     'url': 'https://api.github.com/repos/helciodasilva/apostila-devops',
#     'forks_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/forks',
#     'keys_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/teams',
#     'hooks_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/hooks',
#     'issue_events_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/events',
#     'assignees_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/tags',
#     'blobs_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/languages',
#     'stargazers_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/stargazers',
#     'contributors_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/contributors',
#     'subscribers_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/subscribers',
#     'subscription_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/subscription',
#     'commits_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/merges',
#     'archive_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/downloads',
#     'issues_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/helciodasilva/apostila-devops/deployments',
#     'created_at': '2020-10-28T22:04:42Z',
#     'updated_at': '2020-09-27T21:22:39Z',
#     'pushed_at': '2020-08-29T22:59:25Z',
#     'git_url': 'git://github.com/helciodasilva/apostila-devops.git',
#     'ssh_url': 'git@github.com:helciodasilva/apostila-devops.git',
#     'clone_url': 'https://github.com/helciodasilva/apostila-devops.git',
#     'svn_url': 'https://github.com/helciodasilva/apostila-devops',
#     'homepage': 'https://www.caelum.com.br/curso-devops',
#     'size': 12257,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'other',
#      'name': 'Other',
#      'spdx_id': 'NOASSERTION',
#      'url': None,
#      'node_id': 'MDc6TGljZW5zZTA='},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-10-28T22:04:43Z',
#   'org': {'id': 65012,
#    'login': 'caelum',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/caelum',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65012?'}},
#  {'id': '14007707358',
#   'type': 'PushEvent',
#   'actor': {'id': 52919759,
#    'login': 'tzatushevskaya',
#    'display_login': 'tzatushevskaya',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tzatushevskaya',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52919759?'},
#   'repo': {'id': 298672762,
#    'name': 'tzatushevskaya/Roadmap',
#    'url': 'https://api.github.com/repos/tzatushevskaya/Roadmap'},
#   'payload': {'push_id': 5936810414,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '38ef36af51179788b53334e573f0b2e4ab86f763',
#    'before': '8ab529c2b2aec5d9833df766e48ff0e32316e57e',
#    'commits': [{'sha': '38ef36af51179788b53334e573f0b2e4ab86f763',
#      'author': {'email': '52919759+tzatushevskaya@users.noreply.github.com',
#       'name': 'tzatushevskaya'},
#      'message': 'HW7\n\nTest',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tzatushevskaya/Roadmap/commits/38ef36af51179788b53334e573f0b2e4ab86f763'}]},
#   'public': True,
#   'created_at': '2020-10-28T22:04:43Z'},
#  {'id': '14007707356',
#   'type': 'PushEvent',
#   'actor': {'id': 71558338,
#    'login': 'Heather013',
#    'display_login': 'Heather013',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Heather013',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71558338?'},
#   'repo': {'id': 296906575,
#    'name': 'Heather013/python-lists-lab-data-science-intro-000',
#    'url': 'https://api.github.com/repos/Heather013/python-lists-lab-data-science-intro-000'},
#   'payload': {'push_id': 5936810410,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '21fd191dc69d00b8bcd8c3f3c8de4c0a4897a0fe',
#    'before': '994303ca5817624c0bb3848963a0af7d89f6e580',
#    'commits': [{'sha': '21fd191dc69d00b8bcd8c3f3c8de4c0a4897a0fe',
#      'author': {'email': 'heatherbowman13@gmail.com',
#       'name': 'affable-source-0978'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Heather013/python-lists-lab-data-science-intro-000/commits/21fd191dc69d00b8bcd8c3f3c8de4c0a4897a0fe'}]},
#   'public': True,
#   'created_at': '2020-10-28T22:04:43Z'},
#  {'id': '14007707353',
#   'type': 'PushEvent',
#   'actor': {'id': 70975560,
#    'login': 'JorPan',
#    'display_login': 'JorPan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JorPan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70975560?'},
#   'repo': {'id': 306412970,
#    'name': 'JorPan/ruby-video-hashketball-review-den01-seng-ft-102620',
#    'url': 'https://api.github.com/repos/JorPan/ruby-video-hashketball-review-den01-seng-ft-102620'},
#   'payload': {'push_id': 5936810402,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '02ebd577e80da89e439c6a6f21c70c40fddad226',
#    'before': 'b85a8ba601bb890ef47c58218bc05cb7d79fa2af',
#    'commits': [{'sha': '02ebd577e80da89e439c6a6f21c70c40fddad226',
#      'author': {'email': 'jbpanasewicz@gmail.com',
#       'name': 'Jordan Panasewicz'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JorPan/ruby-video-hashketball-review-den01-seng-ft-102620/commits/02ebd577e80da89e439c6a6f21c70c40fddad226'}]},
#   'public': True,
#   'created_at': '2020-10-28T22:04:43Z'}]

# %% [raw]
# r.json().keys

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception
# - A Timeout exception will be raised if a request times out
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %% [markdown]
# ## Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).

# %% [markdown]
# # Gotta Catch 'Em All! Using the Pokemon API
#
# https://pokeapi.co/
#
# Nice place to start because there's no login details or credentials to fuss with
#
# For now, just want to explore grabbing the Types of different Pokemon.
#
# Useful documentation links:
# - Pokemon endpoint: https://pokeapi.co/docs/v2#pokemon
#     - `https://pokeapi.co/api/v2/pokemon/{id or name}/`
# - Type endpoint: https://pokeapi.co/docs/v2#types
#     - `https://pokeapi.co/api/v2/type/{id or name}/`

# %% [markdown]
# ### Start by exploring the response from the Pokemon endpoint
#
# Going to start with Charmander, pokemon #4, cause he's one of my favorites
#
# <img src="https://i.pinimg.com/originals/e7/0e/d0/e70ed0b54f9230c56c2e3bd2958d68a4.jpg" alt="adorable charmander found via pinterest" width=150>
#
# [Image Source](https://www.pinterest.com/pin/419045940312305352/)

# %%
# First, what endpoint url are we using?
base_poke_url = "https://pokeapi.co/api/v2/pokemon/"

# %%
# How does that need to adapt for charmander?
char_id = 4
char_url = f"{base_poke_url}{char_id}"
# f string - make string that has base arguments in it

# %%
print(char_url)
# Out:
# https://pokeapi.co/api/v2/pokemon/4

# %%
# Check the status code, will this work?
requests.get(char_url).status_code
# Out:
# 200

# %%
# Now let's actually get the response
char_resp = requests.get(char_url).json()

# %%
# Let's check out some details about the response
char_resp.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
char_resp['name']
# Out:
# 'charmander'

# %%
char_resp['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]

# %% [markdown]
# #### Challenge!
#
# Let's write a function that, given a response from this API's pokemon endpoint, returns a list of the ID, name, primary type and secondary type for that pokemon.

# %%
char_resp.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
char_resp['type
# Out:
# 4

# %%
len(char_resp['types'])
# Out:
# 1

# %%
char_resp['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]

# %%
char_resp['types'][0]
# Out:
# {'slot': 1,
#  'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}

# %%
char_resp['types'][0]['type']
# Out:
# {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}

# %%
char_resp['types'][0]['type']['name']
# Out:
# 'fire'

# %%
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, primary type and secondary type 
    '''
    poke_id = poke_resp['id']
    
    poke_name = poke_resp['name']
    
    primary_type = poke_resp['types'][0]['type']['name']
    
    for slot in poke_resp:
        if len(poke_resp['types']) == 2:
            secondary_type = poke_resp['types'][1]['type']['name']
        else:
            secondary_type = 'None'
        return [poke_id, poke_name, primary_type, secondary_type]

# %%
# Let's test our function on the 3 original starter pokemon
original_starters = list(range(1, 8, 3))

# %%
original_starters
# Out:
# [1, 4, 7]

# %%
for poke_id in original_starters:
    poke_url = f"{base_poke_url}{poke_id}" # use charmander example to build for starters
    poke_resp = requests.get(poke_url).json()
    print(get_pokemon_details(poke_resp))
# Out:
# [1, 'bulbasaur', 'grass', 'poison']
# [4, 'charmander', 'fire', 'None']
# [7, 'squirtle', 'water', 'None']

# %% [markdown]
# ### Moving to Pandas
#
# Let's get all of these details for all of the original 151 pokemon! And save them to a Pandas dataframe.

# %%
# Need to import pandas
import pandas as pd

# %%
# Let's go ahead and define what our columns will be
col_names = ['id', 'name', 'primary_type', 'secondary_type']

# %%
# Define a list of our 151 pokemon ids
original_151 = list(range(1,152)) #include mew

# %%
original_151[-5:] #check last 5
# Out:
# [147, 148, 149, 150, 151]

# %% [markdown]
# So we're going to make 151 requests... don't want to overload the API endpoint! So let's use the time library to space out our requests.

# %%
import time

# %%
# Easiest way to do this will be to have a list of lists, then concat them all

# Define a blank list to capture all the pokemon details
row_list = []
# And then loop over our pokemon ids!
for poke_id in original_151:
    poke_url = f"{base_poke_url}{poke_id}" # use starters example
    poke_resp = requests.get(poke_url).json()
    poke_row = (get_pokemon_details(poke_resp))
    row_list.append(poke_row)
    time.sleep(.5) #30 milliseconds

# %%
# Then, concat everything into one df
# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html
poke_df = pd.concat([pd.DataFrame([i], columns=col_names) for i in row_list],
          ignore_index=True)

# %%
poke_df
# Out:
#       id        name primary_type secondary_type
# 0      1   bulbasaur        grass         poison
# 1      2     ivysaur        grass         poison
# 2      3    venusaur        grass         poison
# 3      4  charmander         fire           None
# 4      5  charmeleon         fire           None
# ..   ...         ...          ...            ...
# 146  147     dratini       dragon           None
# 147  148   dragonair       dragon           None
# 148  149   dragonite       dragon         flying
# 149  150      mewtwo      psychic           None
# 150  151         mew      psychic           None
#
# [151 rows x 4 columns]

# %%
prim_type_count = poke_df.groupby('primary_type').count()['id']
prim_type_count
# Out:
# primary_type
# bug         12
# dragon       3
# electric     9
# fairy        2
# fighting     7
# fire        12
# ghost        3
# grass       12
# ground       8
# ice          2
# normal      22
# poison      14
# psychic      8
# rock         9
# water       28
# Name: id, dtype: int64

# %%
# visualize it!
import matplotlib.pyplot as plt

# Let's plot a bar graph of our primary types
plt.figure(figsize = (10,8))
plt.bar(prim_type_count.index, prim_type_count)
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# ![monty python gif - and now for something completely different, from giphy](https://media.giphy.com/media/xznyPebL28X5u/giphy.gif)

# %% [markdown]
# # Movie Time!
#
# Let's practice with an API that actually requires some authorization, in the form of an API Key!

# %% [markdown]
# # **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call. (There are even more options than that, but these are two easily-accessible ones)

# %%
# Option 1: use a json file saved to some other folder outside your Git repo

# Need to import json to do this
import json

# Define a function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Using the function to open and load all keys in that file 
api_keys = get_keys("/Users/lberlin/secrets/api.json") #need to have your own api key

# Setting the first (and only) value as a variable
tmdb_key_1 = api_keys['tmdb_key']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-68-e8c9ca44cceb> in <module>()
#      10
#      11 # Using the function to open and load all keys in that file
# ---> 12 api_keys = get_keys("/Users/lberlin/secrets/api.json")
#      13
#      14 # Setting the first (and only) value as a variable
#
# <ipython-input-68-e8c9ca44cceb> in get_keys(path)
#       6 # Define a function to open the json
#       7 def get_keys(path):
# ----> 8     with open(path) as f:
#       9         return json.load(f)
#      10
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/lberlin/secrets/api.json'

# %%
# Option 2: use a python file that's been added to your .gitignore

# Let's do this together! In a new terminal window,
# Create a file called keys.py in this repo, and I'll save my api key as
# tmdb_api_key = "[key]"

from keys import tmdb_api_key

tmdb_key_2 = tmdb_api_key

# Then let's edit our .gitignore file together

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but **be sure to clear the output of that cell** or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %% [markdown]
# ### And now, accessing movie data
#
# Documentation: https://developers.themoviedb.org/3

# %%
# Default URL given as an example... let's see what it is!
test_url = f"https://api.themoviedb.org/3/movie/550?api_key={tmdb_key_1}"

# %%
# Let's get the response and explore it

# %%
# Find similar movies to the previous id

# %%
# How many similar movies did it find?

# %%
# but is that the length of these results?

# %%
# what's in here?

# %% [markdown]
# -----
#
# ## Extra credit - Further Practice
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
